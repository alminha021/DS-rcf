# %% [markdown]
# <a href="https://colab.research.google.com/github/alminha021/DS-rcf/blob/main/Exercicio5_testes_cana_lista1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Função iterativa de teste- determinar a quantidade de elementos impares na lista:

# %%
def simples(A):
    for i in range(len(A)):
            if A[i]%2 == 1:
                print(A[i])
    return print("fim.")

# %% [markdown]
# Função iterativa- determinar a quantidade de elementos impares na lista:

# %%
def rec(A):
    global variavel_global2
    B = len(A);
    for i in range(0,B,1):
            if A[i]%2 == 1:
                variavel_global2 += 1
                #print(A[i])
    return print("fim: ", variavel_global2)

# %% [markdown]
# Funçao de teste utilizando a tecnica de dividir para conquistar, determina a quantidade de elementos imparis na lista, para exibir os numeros, remover o comentario print(A0[0])

# %%
def recorr2(A0):
    global variavel_global
    B = len(A0);
   # print('tamanho',B)
    if B == 1:
        if A0[0]%2 == 1:
          #  print(A0[0])
            variavel_global += 1
    elif B >= 2:
        mid = B//2
    #    print("mid",mid)
        mid2 = mid+1
   #     print("mid2",mid2)
        A2 = []
        A3 = []
        for j in range (0,mid,1):
            A2.append(A0[j])
    #    print("a2",A2)
        for k in range(mid2 - 1 ,B,1):
            A3.append(A0[k])
  #      print("a3",A3)
        recorr2(A2)
        recorr2(A3)
    return variavel_global
  #  else:
   #     print('nao entra')
    #    print("oi??'", B)

# %% [markdown]
# Duas variaveis contendo numeros inteiros que serao utilizadas para teste

# %%
a = [2,3,5,6,8,9,13,15,16,56,43]
t = 0
b = [1,3,5,6,7,12,13,14,16,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,27,2,24,5,2,7218,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,18,33,45,67,77,88,90,66,53,532,12,13441,1313,123542365,37374,436535,345,435,345354,3543,6437,3,73,52,2,426,2,5,672,2,9999,67,55]

# %% [markdown]
# apenas exibindo a quantidade de numeros em b

# %%
print(len(b))
# Out:
# 1743

# %% [markdown]
# executando a funçao com divisao e conquista na variavel b

# %%
global variavel_global
variavel_global = 0
print('total de impares:', recorr2(b))
# Out:
# total de impares: 980

# %% [markdown]
# executando na variavel b, a funçao simples iterativa para determinar a quantidade de impares

# %%
global variavel_global2
variavel_global2 = 0
rec(b)
# Out:
# fim:  980

# %% [markdown]
# apenas teste do simples, executa uma parte da logica da funçao rec() , menos enfeitado apenas, apenas exibe os numeros impares

# %%
simples(a)
# Out:
# 3
# 5
# 9
# 13
# 15
# 43
# fim.
